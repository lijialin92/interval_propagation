# %%
import matplotlib
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import ticker
# %matplotlib inline

plt.figure()
matplotlib.rc('axes', facecolor = 'white')
matplotlib.rc('figure', figsize = (8,5))
matplotlib.rc('font', size = 14)
matplotlib.rc('axes', grid = True)

plt.xlabel('L infinity perturbation')
plt.ylabel('Certified robustness')

x = [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y1 = [100, 100, 99.8, 99.5, 99.1, 98.6]#large pri, search large
y2 = [100, 100, 99.8, 99.5, 99.1, 98.6]#small pri, search large
y3 = [99.9, 99.5, 97.6, 83.7, 71.1, 62.2]#plain interval propagation
plt.plot(x, y1, color = 'r', marker = 'o')
plt.plot(x, y2, color = 'b', marker = 'v')
plt.plot(x, y3, color = 'g', marker = 's')
plt.legend(['type 1', 'type 2', 'type 3'], loc='lower center')

plt.yticks([100,80,60,40,20,0],
            ["100%", "80%", "60%", "40%", "20%", "0%"])
plt.savefig('l_infinity_perturbation_large_small_pri.png', dpi=300, bbox_inches = 'tight')

# %%
plt.figure()
matplotlib.rc('axes', facecolor = 'white')
matplotlib.rc('figure', figsize = (8,5))
matplotlib.rc('font', size = 14)
matplotlib.rc('axes', grid = True)

plt.xlabel('L infinity perturbation')
plt.ylabel('Certification time(secs)')

x = [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y1 = [1.18, 1.22, 21.51, 52.53, 93.61, 144.89]#large pri, search large
y2 = [1.3, 1.38, 23.45, 55.05, 96.31, 151.07]#small pri, search large
y3 = [45.75, 50.13, 53.47, 52.02, 47.61, 47.28]#plain interval propagation
plt.plot(x, y1, color = 'r', marker = 'o')
plt.plot(x, y2, color = 'b', marker = 'v')
plt.plot(x, y3, color = 'g', marker = 's')
plt.legend(['type 1', 'type 2', 'type 3'], loc='upper center')
plt.savefig('l_infinity_perturbation_large_small_pri_time.png', dpi=300, bbox_inches = 'tight')

# %%
plt.figure()
matplotlib.rc('axes', facecolor = 'white')
matplotlib.rc('figure', figsize = (8,5))
matplotlib.rc('font', size = 14)
matplotlib.rc('axes', grid = True)

plt.xlabel('L infinity perturbation')
plt.ylabel('Certification time(secs)')

x = [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y1 = [1.18, 1.22, 21.51, 52.53, 93.61, 144.89]#large pri, search large
y2 = [1.26, 1.33, 21.65, 52.40, 93.61, 146.38]#small pri, search small

plt.plot(x, y1, color = 'r', marker = 'o')
plt.plot(x, y2, color = 'g', marker = '+')
plt.legend(['search from large to small', 'search from small to large'], loc='upper center')
plt.savefig('l_infinity_perturbation_large_pri_search_time.png', dpi=300, bbox_inches = 'tight')

# %%
plt.figure()
matplotlib.rc('axes', facecolor = 'white')
matplotlib.rc('figure', figsize = (8,5))
matplotlib.rc('font', size = 14)
matplotlib.rc('axes', grid = True)

plt.xlabel('L infinity perturbation')
plt.ylabel('Certification time(secs)')

x = [0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y1 = [1.30, 1.38, 23.45, 55.05, 96.31, 151.07]#large pri, search large
y2 = [1.33, 1.33, 21.93, 763.39, 101.94, 498.31]#small pri, search small

plt.plot(x, y1, color = 'r', marker = 's')
plt.plot(x, y2, color = 'g', marker = '*')
plt.legend(['search from large to small', 'search from small to large'], loc='upper center')
plt.savefig('l_infinity_perturbation_smallest_pri_search_small_time.png', dpi=300, bbox_inches = 'tight')
